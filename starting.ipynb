# %%
import pandas as pd

from datetime import datetime
def time_tango(date, time):
    return datetime.datetime.combine(date, time)

df = pd.read_csv("dataset/EURUSD_M1_202211030000_202211031445.csv",sep="\t")

df["DATE"][0]
# df['DATE'] = df['DATE'].transform(lambda x:pd.to_datetime(x, infer_datetime_format=True))
df['TIME'] = df['TIME'].transform(lambda x:pd.to_datetime(x, infer_datetime_format=True))
# datetime_object = datetime.strptime(datetime_str, '%m/%d/%y')

# %%
df = df[['TIME','OPEN','HIGH','LOW','CLOSE']]
df
# Out:
#                    TIME     OPEN     HIGH      LOW    CLOSE
# 0   2022-11-03 00:00:00  0.98149  0.98195  0.98128  0.98130
# 1   2022-11-03 00:01:00  0.98130  0.98138  0.98128  0.98128
# 2   2022-11-03 00:02:00  0.98128  0.98141  0.98128  0.98141
# 3   2022-11-03 00:03:00  0.98140  0.98140  0.98133  0.98134
# 4   2022-11-03 00:04:00  0.98134  0.98146  0.98134  0.98146
# ..                  ...      ...      ...      ...      ...
# 881 2022-11-03 14:41:00  0.97463  0.97498  0.97434  0.97495
# 882 2022-11-03 14:42:00  0.97495  0.97517  0.97488  0.97503
# 883 2022-11-03 14:43:00  0.97502  0.97502  0.97461  0.97477
# 884 2022-11-03 14:44:00  0.97476  0.97476  0.97451  0.97469
# 885 2022-11-03 14:45:00  0.97470  0.97470  0.97446  0.97446
#
# [886 rows x 5 columns]
